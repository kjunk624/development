# %% [markdown]
# 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 경로지정

# %%
import os
os.chdir("/content/drive/My Drive/Practice")
# %ls
# Out:
# Excise.ipynb  into_01.txt

# %%
1. 실습예제 다음과 같은 into_01.txt 화일을 만들고 화일의 숫자를 읽은 후 1을 더해서 화면에 출력하는 lab01.py화일을 만들자 
into_01.txt
2018

# %%
fstream = open("into_01.txt")
contents = fstream.read()
print(contents)
fstream.close()
# Out:
# 2018

# %%
fstream = open("into_01.txt")
contents = fstream.read()
plus = (int(contents)+1)
print(plus)
fstream.close()
# Out:
# 2019

# %% [markdown]
# 2. 심화예제 다음과 같은 input_02.txt화일을 만들고 각줄의 숫자의 합을 출력하는 프로그램을 작성하시오.
#
# input02.txt
#
# 0
#
# 8
#
# 1
#
# 2

# %%
f = open("input_02.txt", 'w')

numlist='0\n''8\n''1\n''2\n'
f.write(numlist)
print(numlist)
f.close()
# Out:
# 0
# 8
# 1
# 2

# %%
f = open("input_02.txt")
result = 0
numlist2 = f.readlines()
for str_num in numlist2:
    #result = result + int(str_num)
    result +=int(str_num)
print(result)
f.close()
# Out:
# 11
